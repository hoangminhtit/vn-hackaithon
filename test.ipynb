# %%
import pandas as pd

# %%
pred = pd.read_csv("output/pred.csv")
pred.head()
# Out:
#          qid answer
# 0  test_0001      A
# 1  test_0002      A
# 2  test_0003      B
# 3  test_0004      C
# 4  test_0005      A

# %%
result = pd.read_csv("results/test_1780332041.csv")
result.head()
# Out:
#   test_0001 test_0002 test_0003 test_0004 test_0005 test_0006     test_0007  \
# 0         D         B         B         C         C         A             B
# 1       RAG      math       RAG       RAG       RAG      math  multi_domain
#
#   test_0008 test_0009     test_0010  ...     test_0454     test_0455  \
# 0         B         C             B  ...             B             B
# 1      math      math  multi_domain  ...  multi_domain  multi_domain
#
#       test_0456 test_0457 test_0458 test_0459 test_0460     test_0461  \
# 0             C         D         D         C         A             B
# 1  multi_domain      math      math       RAG       RAG  multi_domain
#
#       test_0462     test_0463
# 0             C             B
# 1  multi_domain  multi_domain
#
# [2 rows x 463 columns]

# %%
submission = pd.DataFrame({
    "qid": result.columns,
    "answer": result.iloc[0].values,
    "domain": result.iloc[1].values
})

submission.head()
# Out:
#          qid answer domain
# 0  test_0001      D    RAG
# 1  test_0002      B   math
# 2  test_0003      B    RAG
# 3  test_0004      C    RAG
# 4  test_0005      C    RAG

# %%
merge_ = pd.merge(pred, submission, on="qid", how="left")
merge_.head()
# Out:
#          qid answer_x answer_y domain
# 0  test_0001        A        D    RAG
# 1  test_0002        A        B   math
# 2  test_0003        B        B    RAG
# 3  test_0004        C        C    RAG
# 4  test_0005        A        C    RAG

# %%
a = merge_['answer_x'] == merge_['answer_y']
a.value_counts()
# Out:
# False    294
# True     169
# Name: count, dtype: int64

# %%
diff = merge_[merge_['answer_x'] != merge_['answer_y']]

diff[['qid', 'domain']]
# Out:
#            qid        domain
# 0    test_0001           RAG
# 1    test_0002          math
# 4    test_0005           RAG
# 5    test_0006          math
# 6    test_0007  multi_domain
# ..         ...           ...
# 457  test_0458          math
# 458  test_0459           RAG
# 459  test_0460           RAG
# 461  test_0462  multi_domain
# 462  test_0463  multi_domain
#
# [294 rows x 2 columns]
